# %% [markdown]
# # DS Automation Assignment

# %% [markdown]
# Using our prepared churn data from week 2:
# - use pycaret to find an ML algorithm that performs best on the data
#     - Choose a metric you think is best to use for finding the best model; by default, it is accuracy but it could be AUC, precision, recall, etc. The week 3 FTE has some information on these different metrics.
# - save the model to disk
# - create a Python script/file/module with a function that takes a pandas dataframe as an input and returns the probability of churn for each row in the dataframe
#     - your Python file/function should print out the predictions for new data (new_churn_data.csv)
#     - the true values for the new data are [1, 0, 0, 1, 0] if you're interested
# - test your Python module and function with the new data, new_churn_data.csv
# - write a short summary of the process and results at the end of this notebook
# - upload this Jupyter Notebook and Python file to a Github repository, and turn in a link to the repository in the week 5 assignment dropbox
#
# *Optional* challenges:
# - return the probability of churn for each new prediction, and the percentile where that prediction is in the distribution of probability predictions from the training dataset (e.g. a high probability of churn like 0.78 might be at the 90th percentile)
# - use other autoML packages, such as TPOT, H2O, MLBox, etc, and compare performance and features with pycaret
# - create a class in your Python module to hold the functions that you created
# - accept user input to specify a file using a tool such as Python's `input()` function, the `click` package for command-line arguments, or a GUI
# - Use the unmodified churn data (new_unmodified_churn_data.csv) in your Python script. This will require adding the same preprocessing steps from week 2 since this data is like the original unmodified dataset from week 1.

# %% [markdown]
# # Imports

# %%
import pandas as pd
import sklearn
from pycaret.classification import setup, compare_models, predict_model, save_model, load_model
import warnings
import pickle
import h2o
from h2o.automl import H2OAutoML

#warnings.filterwarnings('ignore')

# %% [markdown]
# ## Load the data

# %%
df = pd.read_csv("prepped_churn_data.csv", index_col='customerID')
df
# Out:
#             tenure  MonthlyCharges  TotalCharges  PhoneService_Yes  \
# customerID
# 7590-VHVEG       1           29.85         29.85                 0
# 5575-GNVDE      34           56.95       1889.50                 1
# 3668-QPYBK       2           53.85        108.15                 1
# 7795-CFOCW      45           42.30       1840.75                 0
# 9237-HQITU       2           70.70        151.65                 1
# ...            ...             ...           ...               ...
# 6840-RESVB      24           84.80       1990.50                 1
# 2234-XADUH      72          103.20       7362.90                 1
# 4801-JZAZL      11           29.60        346.45                 0
# 8361-LTMKD       4           74.40        306.60                 1
# 3186-AJIEK      66          105.65       6844.50                 1
#
#             Contract_One year  Contract_Two year  \
# customerID
# 7590-VHVEG                  0                  0
# 5575-GNVDE                  1                  0
# 3668-QPYBK                  0                  0
# 7795-CFOCW                  1                  0
# 9237-HQITU                  0                  0
# ...                       ...                ...
# 6840-RESVB                  1                  0
# 2234-XADUH                  1                  0
# 4801-JZAZL                  0                  0
# 8361-LTMKD                  0                  0
# 3186-AJIEK                  0                  1
#
#             PaymentMethod_Credit card (automatic)  \
# customerID
# 7590-VHVEG                                      0
# 5575-GNVDE                                      0
# 3668-QPYBK                                      0
# 7795-CFOCW                                      0
# 9237-HQITU                                      0
# ...                                           ...
# 6840-RESVB                                      0
# 2234-XADUH                                      1
# 4801-JZAZL                                      0
# 8361-LTMKD                                      0
# 3186-AJIEK                                      0
#
#             PaymentMethod_Electronic check  PaymentMethod_Mailed check  \
# customerID
# 7590-VHVEG                               1                           0
# 5575-GNVDE                               0                           1
# 3668-QPYBK                               0                           1
# 7795-CFOCW                               0                           0
# 9237-HQITU                               1                           0
# ...                                    ...                         ...
# 6840-RESVB                               0                           1
# 2234-XADUH                               0                           0
# 4801-JZAZL                               1                           0
# 8361-LTMKD                               0                           1
# 3186-AJIEK                               0                           0
#
#             Churn_Yes  total_charges_tenure_ratio  \
# customerID
# 7590-VHVEG          0                   29.850000
# 5575-GNVDE          0                   55.573529
# 3668-QPYBK          1                   54.075000
# 7795-CFOCW          0                   40.905556
# 9237-HQITU          1                   75.825000
# ...               ...                         ...
# 6840-RESVB          0                   82.937500
# 2234-XADUH          0                  102.262500
# 4801-JZAZL          0                   31.495455
# 8361-LTMKD          1                   76.650000
# 3186-AJIEK          0                  103.704545
#
#             monthly_charges_times_tenure
# customerID
# 7590-VHVEG                         29.85
# 5575-GNVDE                       1936.30
# 3668-QPYBK                        107.70
# 7795-CFOCW                       1903.50
# 9237-HQITU                        141.40
# ...                                  ...
# 6840-RESVB                       2035.20
# 2234-XADUH                       7430.40
# 4801-JZAZL                        325.60
# 8361-LTMKD                        297.60
# 3186-AJIEK                       6972.90
#
# [7043 rows x 12 columns]

# %% [markdown]
# The preprocessing was causing an error so I set it to false with all the features set to numeric features.

# %%
features = df.drop('Churn_Yes', axis=1).columns.to_list()
automl = setup(df, target='Churn_Yes', preprocess=False, numeric_features=features, fold_shuffle=True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_e42cf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e42cf_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_e42cf_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e42cf_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e42cf_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_e42cf_row0_col1" class="data row0 col1" >2856</td>
#     </tr>
#     <tr>
#       <th id="T_e42cf_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e42cf_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_e42cf_row1_col1" class="data row1 col1" >Churn_Yes</td>
#     </tr>
#     <tr>
#       <th id="T_e42cf_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e42cf_row2_col0" class="data row2 col0" >Target Type</td>
#       <td id="T_e42cf_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_e42cf_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e42cf_row3_col0" class="data row3 col0" >Label Encoded</td>
#       <td id="T_e42cf_row3_col1" class="data row3 col1" >0: 0, 1: 1</td>
#     </tr>
#     <tr>
#       <th id="T_e42cf_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e42cf_row4_col0" class="data row4 col0" >Original Data</td>
#       <td id="T_e42cf_row4_col1" class="data row4 col1" >(7043, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_e42cf_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e42cf_row5_col0" class="data row5 col0" >Missing Values</td>
#       <td id="T_e42cf_row5_col1" class="data row5 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_e42cf_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_e42cf_row6_col0" class="data row6 col0" >Numeric Features</td>
#       <td id="T_e42cf_row6_col1" class="data row6 col1" >11</td>
#     </tr>
#     <tr>
#       <th id="T_e42cf_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_e42cf_row7_col0" class="data row7 col0" >Categorical Features</td>
#       <td id="T_e42cf_row7_col1" class="data row7 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_e42cf_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_e42cf_row8_col0" class="data row8 col0" >Transformed Train Set</td>
#       <td id="T_e42cf_row8_col1" class="data row8 col1" >(4930, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_e42cf_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_e42cf_row9_col0" class="data row9 col0" >Transformed Test Set</td>
#       <td id="T_e42cf_row9_col1" class="data row9 col1" >(2113, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_e42cf_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_e42cf_row10_col0" class="data row10 col0" >Shuffle Train-Test</td>
#       <td id="T_e42cf_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_e42cf_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_e42cf_row11_col0" class="data row11 col0" >Stratify Train-Test</td>
#       <td id="T_e42cf_row11_col1" class="data row11 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_e42cf_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_e42cf_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_e42cf_row12_col1" class="data row12 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_e42cf_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_e42cf_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_e42cf_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_e42cf_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_e42cf_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_e42cf_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_e42cf_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_e42cf_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_e42cf_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_e42cf_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_e42cf_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_e42cf_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_e42cf_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_e42cf_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_e42cf_row17_col1" class="data row17 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_e42cf_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_e42cf_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_e42cf_row18_col1" class="data row18 col1" >62dd</td>
#     </tr>
#     <tr>
#       <th id="T_e42cf_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_e42cf_row19_col0" class="data row19 col0" >Fix Imbalance</td>
#       <td id="T_e42cf_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_e42cf_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_e42cf_row20_col0" class="data row20 col0" >Fix Imbalance Method</td>
#       <td id="T_e42cf_row20_col1" class="data row20 col1" >SMOTE</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# I'll set the model comparison to sort by recal because we'd like to catch as many customers before they churn as possible.

# %%
best_model = compare_models(sort='Recall')
# Out:
# <style type="text/css">
# #T_6d27a th {
#   text-align: left;
# }
# #T_6d27a_row0_col0, #T_6d27a_row0_col1, #T_6d27a_row0_col2, #T_6d27a_row0_col4, #T_6d27a_row0_col6, #T_6d27a_row0_col7, #T_6d27a_row1_col0, #T_6d27a_row1_col1, #T_6d27a_row1_col2, #T_6d27a_row1_col3, #T_6d27a_row1_col4, #T_6d27a_row1_col5, #T_6d27a_row1_col6, #T_6d27a_row1_col7, #T_6d27a_row2_col0, #T_6d27a_row2_col2, #T_6d27a_row2_col3, #T_6d27a_row2_col5, #T_6d27a_row3_col0, #T_6d27a_row3_col1, #T_6d27a_row3_col2, #T_6d27a_row3_col3, #T_6d27a_row3_col4, #T_6d27a_row3_col5, #T_6d27a_row3_col6, #T_6d27a_row3_col7, #T_6d27a_row4_col0, #T_6d27a_row4_col1, #T_6d27a_row4_col2, #T_6d27a_row4_col3, #T_6d27a_row4_col4, #T_6d27a_row4_col5, #T_6d27a_row4_col6, #T_6d27a_row4_col7, #T_6d27a_row5_col0, #T_6d27a_row5_col1, #T_6d27a_row5_col2, #T_6d27a_row5_col3, #T_6d27a_row5_col4, #T_6d27a_row5_col5, #T_6d27a_row5_col6, #T_6d27a_row5_col7, #T_6d27a_row6_col0, #T_6d27a_row6_col1, #T_6d27a_row6_col3, #T_6d27a_row6_col4, #T_6d27a_row6_col5, #T_6d27a_row6_col6, #T_6d27a_row6_col7, #T_6d27a_row7_col0, #T_6d27a_row7_col1, #T_6d27a_row7_col2, #T_6d27a_row7_col3, #T_6d27a_row7_col4, #T_6d27a_row7_col5, #T_6d27a_row7_col6, #T_6d27a_row7_col7, #T_6d27a_row8_col0, #T_6d27a_row8_col1, #T_6d27a_row8_col2, #T_6d27a_row8_col3, #T_6d27a_row8_col4, #T_6d27a_row8_col5, #T_6d27a_row8_col6, #T_6d27a_row8_col7, #T_6d27a_row9_col0, #T_6d27a_row9_col1, #T_6d27a_row9_col2, #T_6d27a_row9_col3, #T_6d27a_row9_col4, #T_6d27a_row9_col5, #T_6d27a_row9_col6, #T_6d27a_row9_col7, #T_6d27a_row10_col0, #T_6d27a_row10_col1, #T_6d27a_row10_col2, #T_6d27a_row10_col3, #T_6d27a_row10_col4, #T_6d27a_row10_col5, #T_6d27a_row10_col6, #T_6d27a_row10_col7, #T_6d27a_row11_col0, #T_6d27a_row11_col1, #T_6d27a_row11_col2, #T_6d27a_row11_col3, #T_6d27a_row11_col4, #T_6d27a_row11_col5, #T_6d27a_row11_col6, #T_6d27a_row11_col7, #T_6d27a_row12_col0, #T_6d27a_row12_col1, #T_6d27a_row12_col2, #T_6d27a_row12_col3, #T_6d27a_row12_col4, #T_6d27a_row12_col5, #T_6d27a_row12_col6, #T_6d27a_row12_col7, #T_6d27a_row13_col0, #T_6d27a_row13_col1, #T_6d27a_row13_col2, #T_6d27a_row13_col3, #T_6d27a_row13_col4, #T_6d27a_row13_col5, #T_6d27a_row13_col6, #T_6d27a_row13_col7, #T_6d27a_row14_col0, #T_6d27a_row14_col1, #T_6d27a_row14_col2, #T_6d27a_row14_col3, #T_6d27a_row14_col4, #T_6d27a_row14_col5, #T_6d27a_row14_col6, #T_6d27a_row14_col7 {
#   text-align: left;
# }
# #T_6d27a_row0_col3, #T_6d27a_row0_col5, #T_6d27a_row2_col1, #T_6d27a_row2_col4, #T_6d27a_row2_col6, #T_6d27a_row2_col7, #T_6d27a_row6_col2 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_6d27a_row0_col8, #T_6d27a_row2_col8, #T_6d27a_row3_col8, #T_6d27a_row4_col8, #T_6d27a_row5_col8, #T_6d27a_row6_col8, #T_6d27a_row7_col8, #T_6d27a_row8_col8, #T_6d27a_row9_col8, #T_6d27a_row10_col8, #T_6d27a_row11_col8, #T_6d27a_row12_col8, #T_6d27a_row13_col8, #T_6d27a_row14_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_6d27a_row1_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_6d27a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6d27a_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_6d27a_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_6d27a_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_6d27a_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_6d27a_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_6d27a_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_6d27a_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_6d27a_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_6d27a_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6d27a_level0_row0" class="row_heading level0 row0" >qda</th>
#       <td id="T_6d27a_row0_col0" class="data row0 col0" >Quadratic Discriminant Analysis</td>
#       <td id="T_6d27a_row0_col1" class="data row0 col1" >0.7256</td>
#       <td id="T_6d27a_row0_col2" class="data row0 col2" >0.8250</td>
#       <td id="T_6d27a_row0_col3" class="data row0 col3" >0.7860</td>
#       <td id="T_6d27a_row0_col4" class="data row0 col4" >0.4895</td>
#       <td id="T_6d27a_row0_col5" class="data row0 col5" >0.6029</td>
#       <td id="T_6d27a_row0_col6" class="data row0 col6" >0.4105</td>
#       <td id="T_6d27a_row0_col7" class="data row0 col7" >0.4376</td>
#       <td id="T_6d27a_row0_col8" class="data row0 col8" >0.0070</td>
#     </tr>
#     <tr>
#       <th id="T_6d27a_level0_row1" class="row_heading level0 row1" >nb</th>
#       <td id="T_6d27a_row1_col0" class="data row1 col0" >Naive Bayes</td>
#       <td id="T_6d27a_row1_col1" class="data row1 col1" >0.7312</td>
#       <td id="T_6d27a_row1_col2" class="data row1 col2" >0.8149</td>
#       <td id="T_6d27a_row1_col3" class="data row1 col3" >0.7623</td>
#       <td id="T_6d27a_row1_col4" class="data row1 col4" >0.4950</td>
#       <td id="T_6d27a_row1_col5" class="data row1 col5" >0.6001</td>
#       <td id="T_6d27a_row1_col6" class="data row1 col6" >0.4112</td>
#       <td id="T_6d27a_row1_col7" class="data row1 col7" >0.4331</td>
#       <td id="T_6d27a_row1_col8" class="data row1 col8" >0.0060</td>
#     </tr>
#     <tr>
#       <th id="T_6d27a_level0_row2" class="row_heading level0 row2" >ada</th>
#       <td id="T_6d27a_row2_col0" class="data row2 col0" >Ada Boost Classifier</td>
#       <td id="T_6d27a_row2_col1" class="data row2 col1" >0.8037</td>
#       <td id="T_6d27a_row2_col2" class="data row2 col2" >0.8398</td>
#       <td id="T_6d27a_row2_col3" class="data row2 col3" >0.5392</td>
#       <td id="T_6d27a_row2_col4" class="data row2 col4" >0.6592</td>
#       <td id="T_6d27a_row2_col5" class="data row2 col5" >0.5925</td>
#       <td id="T_6d27a_row2_col6" class="data row2 col6" >0.4649</td>
#       <td id="T_6d27a_row2_col7" class="data row2 col7" >0.4694</td>
#       <td id="T_6d27a_row2_col8" class="data row2 col8" >0.0360</td>
#     </tr>
#     <tr>
#       <th id="T_6d27a_level0_row3" class="row_heading level0 row3" >lda</th>
#       <td id="T_6d27a_row3_col0" class="data row3 col0" >Linear Discriminant Analysis</td>
#       <td id="T_6d27a_row3_col1" class="data row3 col1" >0.7892</td>
#       <td id="T_6d27a_row3_col2" class="data row3 col2" >0.8293</td>
#       <td id="T_6d27a_row3_col3" class="data row3 col3" >0.5246</td>
#       <td id="T_6d27a_row3_col4" class="data row3 col4" >0.6220</td>
#       <td id="T_6d27a_row3_col5" class="data row3 col5" >0.5685</td>
#       <td id="T_6d27a_row3_col6" class="data row3 col6" >0.4305</td>
#       <td id="T_6d27a_row3_col7" class="data row3 col7" >0.4336</td>
#       <td id="T_6d27a_row3_col8" class="data row3 col8" >0.0070</td>
#     </tr>
#     <tr>
#       <th id="T_6d27a_level0_row4" class="row_heading level0 row4" >lightgbm</th>
#       <td id="T_6d27a_row4_col0" class="data row4 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_6d27a_row4_col1" class="data row4 col1" >0.7931</td>
#       <td id="T_6d27a_row4_col2" class="data row4 col2" >0.8317</td>
#       <td id="T_6d27a_row4_col3" class="data row4 col3" >0.5192</td>
#       <td id="T_6d27a_row4_col4" class="data row4 col4" >0.6340</td>
#       <td id="T_6d27a_row4_col5" class="data row4 col5" >0.5697</td>
#       <td id="T_6d27a_row4_col6" class="data row4 col6" >0.4355</td>
#       <td id="T_6d27a_row4_col7" class="data row4 col7" >0.4400</td>
#       <td id="T_6d27a_row4_col8" class="data row4 col8" >0.0720</td>
#     </tr>
#     <tr>
#       <th id="T_6d27a_level0_row5" class="row_heading level0 row5" >dt</th>
#       <td id="T_6d27a_row5_col0" class="data row5 col0" >Decision Tree Classifier</td>
#       <td id="T_6d27a_row5_col1" class="data row5 col1" >0.7333</td>
#       <td id="T_6d27a_row5_col2" class="data row5 col2" >0.6673</td>
#       <td id="T_6d27a_row5_col3" class="data row5 col3" >0.5184</td>
#       <td id="T_6d27a_row5_col4" class="data row5 col4" >0.4973</td>
#       <td id="T_6d27a_

# %%
best_model
# Out:
# QuadraticDiscriminantAnalysis(priors=None, reg_param=0.0,
#                               store_covariance=False, tol=0.0001)

# %% [markdown]
# ## Save the model

# %%
save_model(best_model, 'QDA')
# Out:
# Transformation Pipeline and Model Succesfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=True, features_todrop=[],
#                                        id_columns=[],
#                                        ml_usecase='classification',
#                                        numerical_features=['tenure',
#                                                            'MonthlyCharges',
#                                                            'TotalCharges',
#                                                            'PhoneService_Yes',
#                                                            'Contract_One year',
#                                                            'Contract_Two year',
#                                                            'PaymentMethod_Credit '
#                                                            'card (automatic)',
#                                                            'PaymentMethod_Electronic '
#                                                            'check',
#                                                            'PaymentMethod_Mailed '
#                                                            'check',
#                                                            'total_charges_tenure_ratio',
#                                                            'monthly_charges_times_tenure'],
#                                        target='Churn_Yes', time_features=[])),
#                  ['trained_model',
#                   QuadraticDiscriminantAnalysis(priors=None, reg_param=0.0,
#                                                 store_covariance=False,
#                                                 tol=0.0001)]],
#           verbose=False),
#  'QDA.pkl')

# %% [markdown]
# ## Make predictions on new data with python script

# %%
# %run predict_churn.py
# Out:
# Transformation Pipeline and Model Successfully Loaded
#    Churn_predictions  Churn_probability  Churn_percentile
# 0                  0       1.695634e-05               0.6
# 1                  1       1.000000e+00               0.9
# 2                  0       8.055329e-08               0.4
# 3                  0       0.000000e+00               0.2
# 4                  1       1.000000e+00               0.9

# %% [markdown]
# ## H2O autoML

# %%
h2o.init()
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321. connected.
# --------------------------  -----------------------------
# H2O_cluster_uptime:         36 secs
# H2O_cluster_timezone:       Asia/Tokyo
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.44.0.3
# H2O_cluster_version_age:    1 month and 16 days
# H2O_cluster_name:           H2O_from_python_chand_8qhm1m
# H2O_cluster_total_nodes:    1
# H2O_cluster_free_memory:    19.82 Gb
# H2O_cluster_total_cores:    12
# H2O_cluster_allowed_cores:  12
# H2O_cluster_status:         locked, healthy
# H2O_connection_url:         http://localhost:54321
# H2O_connection_proxy:       {"http": null, "https": null}
# H2O_internal_security:      False
# Python_version:             3.11.7 final
# --------------------------  -----------------------------

# %%
hf = h2o.H2OFrame(pd.read_csv('churn_data.csv', index_col='customerID'))
# Out:
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%

# %%
X = hf.columns
y = 'Churn'
X.remove('Churn')

train, test = hf.split_frame(ratios=[.8], seed=101)

train[y] = train[y].asfactor()
test[y] = test[y].asfactor()

aml = H2OAutoML(max_models=10, seed=101)
aml.train(x=X, y=y, training_frame=train)

aml.leaderboard
# Out:
# AutoML progress: |█
# 14:19:02.942: AutoML: XGBoost is not available; skipping it.
#
# ██████████████████████████████████████████████████████████████| (done) 100%
# model_id                                                      auc    logloss     aucpr    mean_per_class_error      rmse       mse
# -------------------------------------------------------  --------  ---------  --------  ----------------------  --------  --------
# StackedEnsemble_BestOfFamily_1_AutoML_3_20240206_141902  0.839112   0.422245  0.649574                0.244858  0.370268  0.137099
# StackedEnsemble_AllModels_1_AutoML_3_20240206_141902     0.838709   0.422565  0.651825                0.241465  0.370451  0.137234
# GBM_1_AutoML_3_20240206_141902                           0.836955   0.424106  0.649281                0.239624  0.370828  0.137513
# GLM_1_AutoML_3_20240206_141902                           0.834314   0.429463  0.620612                0.245348  0.374524  0.140268
# GBM_5_AutoML_3_20240206_141902                           0.83302    0.427868  0.6512                  0.243388  0.372815  0.138991
# DeepLearning_1_AutoML_3_20240206_141902                  0.832294   0.43106   0.619534                0.246207  0.375564  0.141048
# GBM_grid_1_AutoML_3_20240206_141902_model_1              0.830232   0.430665  0.644374                0.245341  0.374016  0.139888
# GBM_2_AutoML_3_20240206_141902                           0.829987   0.430966  0.644923                0.253923  0.37428   0.140085
# GBM_3_AutoML_3_20240206_141902                           0.826678   0.434438  0.639438                0.250688  0.376099  0.14145
# GBM_4_AutoML_3_20240206_141902                           0.821738   0.440302  0.634209                0.254288  0.378788  0.143481
# [12 rows x 7 columns]

# %% [markdown]
# # Summary

# %% [markdown]
# Write a short summary of the process and results here.
